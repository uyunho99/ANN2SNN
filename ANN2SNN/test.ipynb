# %%
import matplotlib.pyplot as plt
import re

# %%
x = """SNN Test Accuracy: 20.240 Time elasped:11.88 s
SNN Test Accuracy: 20.110 Time elasped:23.03 s
SNN Test Accuracy: 20.130 Time elasped:34.14 s
SNN Test Accuracy: 19.770 Time elasped:45.27 s
SNN Test Accuracy: 20.340 Time elasped:56.58 s
SNN Test Accuracy: 20.020 Time elasped:67.96 s
SNN Test Accuracy: 20.370 Time elasped:79.16 s
SNN Test Accuracy: 20.320 Time elasped:90.34 s
SNN Test Accuracy: 20.320 Time elasped:101.54 s
SNN Test Accuracy: 19.670 Time elasped:112.71 s
SNN Test Accuracy: 19.860 Time elasped:123.87 s
SNN Test Accuracy: 20.330 Time elasped:135.04 s
SNN Test Accuracy: 20.100 Time elasped:146.20 s
SNN Test Accuracy: 19.670 Time elasped:157.36 s
SNN Test Accuracy: 20.050 Time elasped:168.52 s
SNN Test Accuracy: 20.220 Time elasped:179.68 s
SNN Test Accuracy: 19.930 Time elasped:190.85 s
SNN Test Accuracy: 19.970 Time elasped:202.02 s
SNN Test Accuracy: 20.140 Time elasped:213.18 s
SNN Test Accuracy: 20.350 Time elasped:224.35 s
SNN Test Accuracy: 20.620 Time elasped:235.51 s
SNN Test Accuracy: 19.540 Time elasped:246.67 s
SNN Test Accuracy: 20.210 Time elasped:257.83 s
SNN Test Accuracy: 20.190 Time elasped:269.00 s
SNN Test Accuracy: 20.140 Time elasped:280.16 s
SNN Test Accuracy: 19.680 Time elasped:291.33 s
SNN Test Accuracy: 20.160 Time elasped:302.49 s"""

accs = re.findall(r' \d+\.\d+', x)
accs
# Out:
# [' 20.240',
#  ' 20.110',
#  ' 20.130',
#  ' 19.770',
#  ' 20.340',
#  ' 20.020',
#  ' 20.370',
#  ' 20.320',
#  ' 20.320',
#  ' 19.670',
#  ' 19.860',
#  ' 20.330',
#  ' 20.100',
#  ' 19.670',
#  ' 20.050',
#  ' 20.220',
#  ' 19.930',
#  ' 19.970',
#  ' 20.140',
#  ' 20.350',
#  ' 20.620',
#  ' 19.540',
#  ' 20.210',
#  ' 20.190',
#  ' 20.140',
#  ' 19.680',
#  ' 20.160']

# %%
accs = [float(acc.strip()) for acc in accs]
accs
# Out:
# [20.24,
#  20.11,
#  20.13,
#  19.77,
#  20.34,
#  20.02,
#  20.37,
#  20.32,
#  20.32,
#  19.67,
#  19.86,
#  20.33,
#  20.1,
#  19.67,
#  20.05,
#  20.22,
#  19.93,
#  19.97,
#  20.14,
#  20.35,
#  20.62,
#  19.54,
#  20.21,
#  20.19,
#  20.14,
#  19.68,
#  20.16]

# %%
plt.plot(accs)
